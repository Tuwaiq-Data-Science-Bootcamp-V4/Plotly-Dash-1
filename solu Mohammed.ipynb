# %% [markdown]
# # Q0: import dash standard libraries

# %%
from dash import Dash, dcc, html, Input, Output, callback
from jupyter_dash import JupyterDash
import warnings
warnings.filterwarnings("ignore")

# %%
app = JupyterDash()

# %% [markdown]
# # Q1: Make dash that prints "Data Science"

# %%
app.layout = html.H1("Data Science", style={"textAlign": "center"})
app.run(port=8091)

# %% [markdown]
# # Q2: Make dash that takes name input and outpt "Welcome to Data Science dashboard {name}"

# %%
app.layout = html.Div([
    dcc.Input(id='input',value='',),
    html.Div(id='output', style={'whiteSpace': 'pre-line'})
])

@callback(
    Output('output', 'children'),
    Input('input', 'value')
)
def update_output(value):
    return 'Welcome to Data Science dashboard {}'.format(value)

app.run_server(port=9877)

# %% [markdown]
# # Q3: Make Plotly-Dash that takes two inputs (numbers) and output 3 numbers x, y , z= x+y
# - hint: use html.Div, dcc.Input(type='number')

# %%
app.layout = html.Div([
    dcc.Input(type='number',
        id='first-number',
        value='',
        
    ),
    dcc.Input(type='number',
        id='second-number',
        value='',
        
    ),
    html.Div( id='output', style={'whiteSpace': 'pre-line'})
])

@callback(
    Output('output', 'children'),
    Input('first-number' , 'value'),
    Input('second-number', 'value')
)
def update_output(x, y):
    return f'{x+y}'


app.run(port=4607)

# %% [markdown]
# # Q4.1: Make JubyterDash with Rangeslider from 1-15 with 6 option

# %%
app.layout = html.Div([
    html.H1("Rangeslider", style={"textAlign": "center"}),
    dcc.RangeSlider(0,15,3, id="slid", value=[1,6]
    ),

    html.Div(id='output', style={'whiteSpace': 'pre-line'})
])

@callback(
    Output('output', 'children'),
    Input('slid', 'value')
)
def update_output(x):
    return x


app.run_server(port=9076)

# %% [markdown]
# # Q4.2: add to the previous dash: Label, set default value on rangeslider as 7-10

# %%
app.layout = html.Div([
    html.H1("Rangeslider", style={"textAlign": "center"}),
    dcc.RangeSlider(0,15,3, id="slid", 
                            marks={
                            0: 'zero',
                            3: "Three",
                            6: 'Six',
                            9: 'Nine',
                            12: "Twelve",
                            15: "Fifteen"
            },
                    value=[7,10]),
    html.Label("Range"),

    html.Div(id='output', style={'whiteSpace': 'pre-line'})
])

@callback(
    Output('output', 'children'),
    Input('slid', 'value')
)
def update_output(x):
    return x


app.run_server(port=4996)

# %% [markdown]
# # Q5: Make 3 different Dcc types (Dropdown - Checkbox...) in one dash

# %%
app.layout = html.Div([
    html.H1("Rangeslider", style={"textAlign": "center"}),
    dcc.RangeSlider(0,15,3, id="slid", value=[1,6]
    ),
    dcc.Dropdown(['one', 'two', 'three'], 'one', id='demo-dropdown'),
    html.Div(id='output', style={'whiteSpace': 'pre-line'}),
    dcc.Checklist(    ['one', 'two', 'three'],
                        ['New York City', 'Montréal'],inline=True)
])

@callback(
    Output('output', 'children'),
    Input('slid', 'value')
)
def update_output(x):
    return x


app.run_server(port=9906)

# %% [markdown]
# # Q6: Make Plotly chart, then add it to a plotly_dash

# %%
import plotly.express as px

# %%
app = JupyterDash(external_stylesheets=[dbc.themes.LUX])

# %%
ex = pd.DataFrame({"Name": ["Ahmed", "Saud", "Fahad"],
                  "Age": [40, 35, 25]})
fig_1 = px.bar(ex, x="Name", y="Age")
app.layout = html.Div([
    html.H1("Age Bar"),
    dcc.Graph(
    id="fig1",
    figure=fig_1
    )
])
app.run_server()

# %% [markdown]
# # Q7: From our data make plotly-dash with suitble chart, and Dropdown.
#
# - Dropdown should contain at least 3 options, each one represents different column.
# - Add label to dropdown.
# - The chart data should change depending on the selected dropdown option.

# %%
import pandas as pd
df = pd.read_csv("titanic passenger list.csv")
df["survived"] = df["survived"].astype(str)
df["survived"][df["survived"] == "1.0"] = "alive"
df["survived"][df["survived"] == "0.0"] = "died"
df
# Out:
#       pclass survived                                             name  \
# 0        1.0    alive                    Allen, Miss. Elisabeth Walton
# 1        1.0    alive                   Allison, Master. Hudson Trevor
# 2        1.0     died                     Allison, Miss. Helen Loraine
# 3        1.0     died             Allison, Mr. Hudson Joshua Creighton
# 4        1.0     died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...      ...                                              ...
# 1304     3.0     died                             Zabour, Miss. Hileni
# 1305     3.0     died                            Zabour, Miss. Thamine
# 1306     3.0     died                        Zakarian, Mr. Mapriededer
# 1307     3.0     died                              Zakarian, Mr. Ortin
# 1308     3.0     died                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
dfxx = pd.DataFrame({"sex": ["male", "female"],
                        "count": [841, 464]})

dfxx
# Out:
#       sex  count
# 0    male    841
# 1  female    464

# %%
app = JupyterDash()



app.layout = html.Div(children=[
    html.Br(),
    html.H1('Survived Counts', style={'text-align': 'center', 'color': 'white'}),

    # Dropdown
    dcc.Dropdown(
        id='my-drop',
        options=["age", "sex", "survived"],
        value='age' # Set initial value
    ),

    # Graph
    dcc.Graph(id='my-graph')
])


@app.callback(
    Output('my-graph', 'figure'),
    Input('my-drop', 'value')
)
def update_graph(val):
    
    filtered_df = df[val]
    bar_chart = px.histogram(filtered_df, x=val, title=f'Survived in {val} ')
    return bar_chart


if __name__ == '__main__':
    app.run()

# %% [markdown]
# # Q8: add 2 more charts to the prevoius Ploty-Dash

# %%
app = JupyterDash()


fig = px.pie(dfxx,names="sex", values="count")


fig2 = px.pie(df, )

app.layout = html.Div(children=[
    html.Br(),
    html.H1('Survived Counts', style={'text-align': 'center', 'color': 'white'}),

    # Dropdown
    dcc.Dropdown(
        id='my-drop',
        options=["age", "sex", "survived"],
        value='age' # Set initial value
    ),

    # Graph
    dcc.Graph(id='my-graph'),
    dcc.Graph(id='my-graph1',
             figure=fig)
])


@app.callback(
    Output('my-graph', 'figure'),
    Input('my-drop', 'value')
)
def update_graph(val):
    
    filtered_df = df[val]
    bar_chart = px.histogram(filtered_df, x=val, title=f'Survived in {val} ')
    return bar_chart


if __name__ == '__main__':
    app.run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Q9: Search for "Plotly Gallery" and fetch for a graph and use it with our data.
#
# - Note: You need to put the resourse addres of fetched your grapth.

# %%
#  Source https://plotly.com/python/setting-graph-size/
fig = px.scatter(df, x="sex", y="age", facet_col="sex",
                 width=800, height=400)

fig.update_layout(
    margin=dict(l=20, r=20, t=20, b=20),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <div>                            <div id="a265d713-cc69-4362-aca5-b7d26da38369" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a265d713-cc69-4362-aca5-b7d26da38369")) {                    Plotly.newPlot(                        "a265d713-cc69-4362-aca5-b7d26da38369",                        [{"hovertemplate":"sex=%{x}\u003cbr\u003eage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female","female",
# ...

# %% [markdown]
# # Challenge 1.1: Create Plotly dash with two charts depends on different columns of the data
# - First Chart : Pie
# - Secound Chart: is by your Choice ( Not Pie )

# %% [markdown]
# # Challenge 1.2: Make Hovering over a slice of the pie changes the data for the second chart depending on what the slice is.
